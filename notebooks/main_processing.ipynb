# %% [markdown]
# # what to run on command line to process files

# %% [markdown]
# #### rootfolder = "/Volumes/2024release/sample_data"
# #### codefolder = "/Users/nayoonkim/pipeline_imaging/aireadi_retinal_imaging/year_3"
# #### these process_xxx.py files are in /aireadi_retinal_imaging/main
#
# #### --flio--
# ##### python process_flio.py -i "rootfolder/flio/input" -o  "rootfolder/flio/output" -j "codefolder/flio_uid_data.json"
#
# python process_flio.py -i "/Volumes/2024release/sample_data/flio/input" -o  "/Volumes/2024release/sample_data/flio/output" -j "/Users/nayoonkim/pipeline_imaging/aireadi_retinal_imaging/year_3/flio_uid_data.json"
#
# #### --optomed--
# ##### python process_optomed.py -i "rootfolder/optomed/input" -o "rootfolder/optomed/output"
#
# python process_optomed.py -i "/Volumes/2024release/sample_data/optomed/input" -o  "/Volumes/2024release/sample_data/optomed/output"
#
#
# #### --eidon--
# ##### python process_eidon.py -i "rootfolder/eidon/input" -o "rootfolder/eidon/output"
#
# python process_eidon.py -i "/Volumes/2024release/sample_data/eidon/input" -o  "/Volumes/2024release/sample_data/eidon/output"
#
# #### --spectralis--
# ##### python process_spectralis.py -i "rootfolder/spectralis/input" -o "rootfolder/spectralis/output"
#
# python process_spectralis.py -i "/Volumes/2024release/sample_data/spectralis/input" -o  "/Volumes/2024release/sample_data/spectralis/output"
#
# #### --maestro2--
# ##### python process_topcon.py -i "rootfolder/maestro2/input" -o "rootfolder/maestro2/output"
#
# python process_topcon.py -i "/Volumes/2024release/sample_data/maestro2/input" -o  "/Volumes/2024release/sample_data/maestro2/output"
#
# #### --triton--
# ##### python process_topcon.py -i "rootfolder/triton/input" -o "rootfolder/triton/output"
#
# python process_topcon.py -i "/Volumes/2024release/sample_data/triton/input" -o  "/Volumes/2024release/sample_data/triton/output"
#
# #### --cirrus--
# ##### python process_cirrus.py -i "rootfolder/cirrus/input" -o "rootfolder/cirrus/output"
#
# python process_cirrus.py -i "/Volumes/2024release/sample_data/cirrus/input" -o  "/Volumes/2024release/sample_data/cirrus/output"
#
# #### --compliance check--
# ##### python3 create_compliance_report.py "rootfolder/compliance/inputfiles" "name_this_set_of_reports" "rootfolder/compliance/outputfiles"
#
# python3 create_compliance_report.py "/Volumes/2024release/sample_data/compliance_check/input" "maestro2_check" "/Volumes/2024release/sample_data/compliance_check/output"
